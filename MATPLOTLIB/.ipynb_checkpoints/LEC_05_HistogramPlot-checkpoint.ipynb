# %% [markdown]
# # HISTOGRAM PLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

array = np.random.randint(10 , 60 , (50)) # Number is between 10-60 and 50 data are needed
print(array)
# Out:
# [19 40 24 25 30 33 33 50 29 51 35 44 21 10 25 26 40 10 53 12 59 35 16 54
#  24 33 42 39 29 49 46 48 22 30 10 25 34 28 19 55 57 55 39 14 10 25 55 19
#  18 42]

# %%
number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]

plt.hist(number , color="b" , edgecolor="r" , linewidth = 4)
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number , color="b" , edgecolor="r" , bins=l , linewidth = 4) # Using bins: all data between 10-20 is plotted is in 1st bar
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number ,"auto", (0 , 200), edgecolor="r") # HERE X-AXIS RANGE IS SET (0-200),
                                                   # BUT NOTE! RANGE IS SET TOBE 3RD PARAMETER IN .hist() 
plt.show()

# %%
number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]

plt.hist(number , color="b" ,edgecolor="r", cumulative=-1 , bottom = 10)
# cumulative ,set your bars in  Ascending or Descending order, based
# Upon it's value. -1 for Descending order and +1 for Ascending order
# Bottom parameter is set your x-origin i.e bottom paremeter to an input value
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number , color="b" , edgecolor="r" , bins=l , align = "mid")  # align = ??
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number , color="b" , edgecolor="r" , bins=l , histtype = "step")  # histtype = "step" and "stepfilled" and "barstacked" and "bar"
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number , color="b" , edgecolor="r" , bins=l , orientation="horizontal" , rwidth = 0.8) 

# The default value of rwidth is 0.9 which means that the bars will have a width of 90% of the width of the bin.
# By changing the value of rwidth, we can adjust the spacing between the bars in the histogram plot.
# In the given code, rwidth=0.8 is used which means that the width of the bars will be 80% of the width of the bin.
# First it captures 100% width of the bin .Now it reduce to 80 % ,20% width is deducted from each of the bars.
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]
plt.hist(number , color="b" , edgecolor="r" , bins=l ,log = True , label = "Python") 
plt.xlabel("LOG TABLE" , fontsize = 15 , color="m")
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

number = [19, 40, 24, 25, 30, 33, 33, 50, 29, 51, 35, 44, 21, 10, 25, 26, 40, 10, 53, 12, 59, 35, 16, 54,
 24, 33, 42, 39, 29, 49, 46, 48, 22, 30, 10, 25, 34, 28, 19, 55, 57, 55, 39, 14, 10, 25, 55, 19,
 18, 42]
l = [10 , 20 , 30 , 40 , 50 , 60]

plt.hist(number , edgecolor="r" , bins=l ,log = True , label = "Python") 
plt.xlabel("LOG TABLE" , fontsize = 15 , color="m")
plt.title("Histogram plot" , color="r" , fontsize = 15)
plt.axvline(40 , color="g", label="Value 1")
plt.axvline(50 , color="r", label="Value 2")
plt.grid()
plt.legend()
plt.show()
