# %% [markdown]
# # PLOTLY SCATTER CHART

# %%
import plotly.offline as pyo
import pandas as pd
import matplotlib.pyplot as plt

# %%
orders = pd.read_excel("sales.xlsx")
orders
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
import plotly.graph_objs as go

# %%
orders_sf = orders[["Sales" , "Profit"]].head()
orders_sf
# Out:
#         Sales     Profit
# 0    261.5400  -213.2500
# 1  10123.0200   457.8100
# 2    244.5700    46.7075
# 3   4965.7595  1198.9710
# 4    394.2700    30.9400

# %%
import plotly.graph_objs as go
import plotly.offline as pyo

data = go.Scatter(
    x=orders_sf.Sales,
    y=orders_sf.Profit,
    mode='markers',
    marker = dict(
        
        size = 14,
        color = 'rgb(120 , 150 , 180)',
        symbol = "square",
        line = dict(        # It basically the Border Width of each Block.
            width = 2,
        
        )
    )
)

layout = go.Layout(
    title=dict(text='Sales vs. Profit', font=dict(color='red', family='Arial')),
    xaxis=dict(title='Sales', tickfont=dict(color='red', family='Arial')),
    yaxis=dict(title='Profit', tickfont=dict(color='red', family='Arial')),
)

fig = go.Figure(data=[data], layout=layout)
pyo.plot(fig)
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\arups\\Jupyter Notebook\\PLOTLY'
