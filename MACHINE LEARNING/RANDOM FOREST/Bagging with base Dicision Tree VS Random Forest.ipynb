# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.535272 -0.641948  0.019017 -0.151077  0.223567       0
# 1  2.263534  2.501872 -2.338184 -0.371834 -1.039734       0
# 2  0.955658  3.180001 -0.041512  0.017924  0.508737       0
# 3 -0.099276  0.096240 -1.365778 -2.596092 -1.798925       0
# 4  0.976629 -0.999681  1.265483  0.607245 -0.428787       1

# %%
bag = BaggingClassifier(max_features=2)
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
print(bag.estimators_)
plt.show()
# Out:
# [DecisionTreeClassifier(random_state=1913710819), DecisionTreeClassifier(random_state=1720543904), DecisionTreeClassifier(random_state=1142169204), DecisionTreeClassifier(random_state=2009711236), DecisionTreeClassifier(random_state=1670666672), DecisionTreeClassifier(random_state=562072374), DecisionTreeClassifier(random_state=1825991495), DecisionTreeClassifier(random_state=192294378), DecisionTreeClassifier(random_state=1560962562), DecisionTreeClassifier(random_state=2059044293)]

# %%
rf = RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
