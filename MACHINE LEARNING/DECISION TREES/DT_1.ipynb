# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X = iris.data

# %%
y = iris.target

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test , y_pred)
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree
from matplotlib.pyplot import rcParams

# The rcParams object in matplotlib is used to customize various properties 
# of the plots and figures generated by the library. It stands for "runtime configuration parameters"
# and allows you to modify the default settings of matplotlib to suit your specific needs.

rcParams['figure.figsize'] = 80 , 50 # width x height
plot_tree(clf)
# Out:
# [Text(0.3181818181818182, 0.9285714285714286, 'x[3] <= 0.8\ngini = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(0.22727272727272727, 0.7857142857142857, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.4090909090909091, 0.7857142857142857, 'x[2] <= 4.75\ngini = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(0.18181818181818182, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.09090909090909091, 0.5, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.2727272727272727, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6363636363636364, 0.6428571428571429, 'x[3] <= 1.75\ngini = 0.165\nsamples = 44\nvalue = [0, 4, 40]'),
#  Text(0.45454545454545453, 0.5, 'x[2] <= 5.35\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]'),
#  Text(0.36363636363636365, 0.35714285714285715, 'x[3] <= 1.55\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\arups\\OneDrive\\Desktop\\COLLECTION\\PROGRAMS\\TEST_CSVs\\Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Gender'].replace({'Male' : 0 , 'Female': 1} , inplace = True)

# %%
X = df.iloc[: , 1:4].values # array([[0,19,19000],[0,35,20000],..[n,n,n]] ,  dtype=int64)
y = df.iloc[: , -1].values

# %%
X.shape
# Out:
# (400, 3)

# %%
y.shape
# Out:
# (400,)

# %%
# OVER FITTING
clf1 = DecisionTreeClassifier()
clf1.fit(X , y)
rcParams['figure.figsize'] = 80 , 50 # width x height
plot_tree(clf1)
# Out:
# [Text(0.44252232142857145, 0.9666666666666667, 'x[1] <= 42.5\ngini = 0.459\nsamples = 400\nvalue = [257, 143]'),
#  Text(0.23325892857142858, 0.9, 'x[2] <= 90500.0\ngini = 0.271\nsamples = 285\nvalue = [239, 46]'),
#  Text(0.109375, 0.8333333333333334, 'x[1] <= 36.5\ngini = 0.072\nsamples = 241\nvalue = [232, 9]'),
#  Text(0.09151785714285714, 0.7666666666666667, 'gini = 0.0\nsamples = 162\nvalue = [162, 0]'),
#  Text(0.12723214285714285, 0.7666666666666667, 'x[2] <= 83500.0\ngini = 0.202\nsamples = 79\nvalue = [70, 9]'),
#  Text(0.109375, 0.7, 'x[2] <= 67500.0\ngini = 0.165\nsamples = 77\nvalue = [70, 7]'),
#  Text(0.09151785714285714, 0.6333333333333333, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(0.12723214285714285, 0.6333333333333333, 'x[2] <= 70500.0\ngini = 0.307\nsamples = 37\nvalue = [30, 7]'),
#  Text(0.08035714285714286, 0.5666666666666667, 'x[1] <= 39.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0625, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
# OVER FITTING REDUCED BY 'max_depth'

clf1 = DecisionTreeClassifier(max_depth=3)
clf1.fit(X , y)
rcParams['figure.figsize'] = 80 , 50 # width x height
plot_tree(clf1)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 42.5\ngini = 0.459\nsamples = 400\nvalue = [257, 143]'),
#  Text(0.25, 0.625, 'x[2] <= 90500.0\ngini = 0.271\nsamples = 285\nvalue = [239, 46]'),
#  Text(0.125, 0.375, 'x[1] <= 36.5\ngini = 0.072\nsamples = 241\nvalue = [232, 9]'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 162\nvalue = [162, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.202\nsamples = 79\nvalue = [70, 9]'),
#  Text(0.375, 0.375, 'x[2] <= 119000.0\ngini = 0.268\nsamples = 44\nvalue = [7, 37]'),
#  Text(0.3125, 0.125, 'gini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.4375, 0.125, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.75, 0.625, 'x[1] <= 46.5\ngini = 0.264\nsamples = 115\nvalue = [18, 97]'),
#  Text(0.625, 0.375, 'x[2] <= 35500.0\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.5625, 0.125, 'gini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6875, 0.125, 'gini = 0.492\nsamples = 16\nvalue = [7, 9]'),
# ...
